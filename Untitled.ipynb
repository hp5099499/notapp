# %%
import pandas as pd
df=pd.read_csv("equity_issuers.csv")
df.head()
# Out:
#                             Security Code Issuer Name  \
# 500002                  ABB India Limited         ABB
# 500003               Aegis Logistics Ltd.    AEGISLOG
# 500008           Amara Raja Batteries Ltd  AMARAJABAT
# 500009  Ambalal Sarabhai Enterprise Ltd.,   AMBALALSA
# 500012        Andhra Petrochemicals Ltd.,   ANDHRAPET
#
#                               Security Id Security Name Status  Group  \
# 500002                  ABB India Limited        Active     A     2.0
# 500003               AEGIS LOGISTICS LTD.        Active     A     1.0
# 500008          AMARA RAJA BATTERIES LTD.        Active     A     1.0
# 500009  AMBALAL SARABHAI ENTERPRISES LTD.        Active     X    10.0
# 500012         ANDHRA PETROCHEMICALS LTD.        Active     X    10.0
#
#           Face Value                       ISIN No Industry  \
# 500002  INE117A01022    Heavy Electrical Equipment   Equity
# 500003  INE208C01025                 Trading - Gas   Equity
# 500008  INE885A01032  Auto Components & Equipments   Equity
# 500009  INE432A01017               Pharmaceuticals   Equity
# 500012  INE714B01016           Commodity Chemicals   Equity
#
#                     Instrument                     Sector Name  \
# 500002             Industrials                   Capital Goods
# 500003                  Energy     Oil, Gas & Consumable Fuels
# 500008  Consumer Discretionary  Automobile and Auto Components
# 500009              Healthcare                      Healthcare
# 500012             Commodities                       Chemicals
#
#                       Industry New Name                   Igroup Name  \
# 500002             Electrical Equipment    Heavy Electrical Equipment
# 500003                              Gas                 Trading - Gas
# 500008                  Auto Components  Auto Components & Equipments
# 500009  Pharmaceuticals & Biotechnology               Pharmaceuticals
# 500012       Chemicals & Petrochemicals           Commodity Chemicals
#
#         ISubgroup Name
# 500002             NaN
# 500003             NaN
# 500008             NaN
# 500009             NaN
# 500012             NaN

# %%
unique_sectors = df['Sector Name'].drop_duplicates().tolist()
unique_sectors
# Out:
# ['Capital Goods',
#  'Oil, Gas & Consumable Fuels',
#  'Automobile and Auto Components',
#  'Healthcare',
#  'Chemicals',
#  'Realty',
#  'Metals & Mining',
#  'Consumer Services',
#  'Textiles',
#  'Consumer Durables',
#  'Fast Moving Consumer Goods',
#  'Financial Services',
#  'Forest Materials',
#  'Media, Entertainment & Publication',
#  'Telecommunication',
#  'Power',
#  'Services',
#  'Diversified',
#  'Information Technology',
#  'Construction',
#  'Construction Materials',
#  'Utilities',
#  '-']

# %%
total_sectors = df['Sector Name'].nunique()
total_sectors
# Out:
# 23

# %%
unique_sectors = df['Sector Name'].drop_duplicates().tolist()
]
technology_stocks
# Out:
#                                  Security Code Issuer Name  \
# 500179                     HCL Infosystems Ltd   HCL-INSYS
# 500209                             Infosys Ltd        INFY
# 500408                          Tata Elxsi Ltd   TATAELXSI
# 500463                       BLACK BOX LIMITED        BBOX
# 501421            TechNVision Ventures Limited   TECHNVISN
# ...                                        ...         ...
# 543931                VEEFIN SOLUTIONS LIMITED      VEEFIN
# 543938              ACCELERATEBS INDIA LIMITED  ACCELERATE
# 543945       NETWEB TECHNOLOGIES INDIA LIMITED      NETWEB
# 543958  VL E-Governance & IT Solutions Limited      VLEGOV
# 590051                         Saksoft Limited     SAKSOFT
#
#                                Security Id Security Name Status  Group  \
# 500179                HCL INFOSYSTEMS LTD.        Active     T     2.0
# 500209                        INFOSYS LTD.        Active     A     5.0
# 500408                     TATA ELXSI LTD.        Active     A    10.0
# 500463                       Black Box Ltd        Active     B     2.0
# 501421           TECHNVISION VENTURES LTD.        Active     XT   10.0
# ...                                    ...           ...    ...    ...
# 543931                Veefin Solutions Ltd        Active     M    10.0
# 543938              Acceleratebs India Ltd        Active     M    10.0
# 543945       Netweb Technologies India Ltd        Active     B     2.0
# 543958  VL E-Governance & IT Solutions Ltd        Active     T    10.0
# 590051                        SAKSOFT LTD.        Active     B     1.0
#
#           Face Value                            ISIN No Industry  \
# 500179  INE236A01020    Computers Hardware & Equipments   Equity
# 500209  INE009A01021  Computers - Software & Consulting   Equity
# 500408  INE670A01012  Computers - Software & Consulting   Equity
# 500463  INE676A01027                IT Enabled Services   Equity
# 501421  INE314H01012                  Software Products   Equity
# ...              ...                                ...      ...
# 543931  INE0Q0M01015                IT Enabled Services   Equity
# 543938  INE0POP01017  Computers - Software & Consulting   Equity
# 543945  INE0NT901020    Computers Hardware & Equipments   Equity
# 543958  INE03HW01020                IT Enabled Services   Equity
# 590051  INE667G01023  Computers - Software & Consulting   Equity
#
#                     Instrument             Sector Name Industry New Name  \
# 500179  Information Technology  Information Technology     IT - Hardware
# 500209  Information Technology  Information Technology     IT - Software
# 500408  Information Technology  Information Technology     IT - Software
# 500463  Information Technology  Information Technology     IT - Services
# 501421  Information Technology  Information Technology     IT - Software
# ...                        ...                     ...               ...
# 543931  Information Technology  Information Technology     IT - Services
# 543938  Information Technology  Information Technology     IT - Software
# 543945  Information Technology  Information Technology     IT - Hardware
# 543958  Information Technology  Information Technology     IT - Services
# 590051  Information Technology  Information Technology     IT - Software
#
#                               Igroup Name  ISubgroup Name
# 500179    Computers Hardware & Equipments             NaN
# 500209  Computers - Software & Consulting             NaN
# 500408  Computers - Software & Consulting             NaN
# 500463                IT Enabled Services             NaN
# 501421                  Software Products             NaN
# ...                                   ...             ...
# 543931                IT Enabled Services             NaN
# 543938  Computers - Software & Consulting             NaN
# 543945    Computers Hardware & Equipments             NaN
# 543958                IT Enabled Services             NaN
# 590051  Computers - Software & Consulting             NaN
#
# [195 rows x 14 columns]
